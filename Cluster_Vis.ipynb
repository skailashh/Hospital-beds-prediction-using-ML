# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Import the dataset
madrid = pd.read_csv("Madrid_database.csv", header=0)
print(madrid.head())

# Convert 'Date' column to datetime format
madrid['Date'] = pd.to_datetime(madrid['Date'])
print(madrid.dtypes)

# Sort the dataset by date in ascending order
madrid.sort_values(by='Date', inplace=True)

# Specify target variable (y)
y = madrid[['Target_1', 'Target_2', 'Target_3', 'Target_4', 'Target_5', 'Target_6', 'Target_7']]

# Drop columns related to lag features and target variables
X = madrid.drop(['Date', 'Target_1', 'Target_2', 'Target_3', 'Target_4', 'Target_5', 'Target_6', 'Target_7'], axis=1)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Display the shapes of the training and testing sets
print("Training set shapes:", X_train.shape, y_train.shape)
print("Testing set shapes:", X_test.shape, y_test.shape)
# Out:
#          Date  Day_of_week  Holiday  Moon_Phase  Average_Temp  Max_temp  \
# 0  08/09/2018            6        0           5        295.01    299.30
# 1  09/09/2018            7        0           1        295.68    302.16
# 2  10/09/2018            1        0           0        296.24    302.14
# 3  11/09/2018            2        0           1        296.40    303.19
# 4  12/09/2018            3        0           4        297.18    303.88
#
#    Average_wind  Max_wind  Average_mslp  Total_precipitation  ...  ED_5  ED_6  \
# 0          2.56      3.96     101703.64              0.00281  ...  20.0  13.0
# 1          1.26      3.03     101901.04              0.00012  ...  14.0  20.0
# 2          2.44      3.57     102190.41              0.00014  ...  14.0  14.0
# 3          2.36      3.57     102223.68              0.00139  ...  14.0  14.0
# 4          1.39      2.95     102153.50              0.00001  ...  12.0  14.0
#
# ...

# %%
from sklearn.cluster import KMeans

# Number of clusters
n_clusters = 3

# Fit KMeans clustering model to the training data
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(X_train)

# Predict cluster labels for the training and testing data
train_clusters = kmeans.predict(X_train)
test_clusters = kmeans.predict(X_test)

# Combine the training data with the cluster labels
train_df_with_clusters = pd.DataFrame(X_train, columns=X.columns)
train_df_with_clusters['Cluster'] = train_clusters

# %%
col = 'Average_Temp'

plt.figure(figsize=(10, 6))
sns.kdeplot(data=train_df_with_clusters, x=col, hue='Cluster', fill=True, common_norm=False)
plt.title(f'Density Distribution of {col} Across Clusters')
plt.xlabel(col)
plt.ylabel('Density')

# Add legend
plt.legend(title='Cluster', labels=[f'Cluster {i}' for i in range(n_clusters)])

plt.show()

# %%
col = 'Day_of_week'


plt.figure(figsize=(10, 6))
sns.kdeplot(data=train_df_with_clusters, x=col, hue='Cluster', fill=True, common_norm=False)
plt.title(f'Density Distribution of {col} Across Clusters')
plt.xlabel(col)
plt.ylabel('Density')

# Add legend
plt.legend(title='Cluster', labels=[f'Cluster {i}' for i in range(n_clusters)])

plt.show()

# %%
col = 'Max_temp'

plt.figure(figsize=(10, 6))
sns.kdeplot(data=train_df_with_clusters, x=col, hue='Cluster', fill=True, common_norm=False)
plt.title(f'Density Distribution of {col} Across Clusters')
plt.xlabel(col)
plt.ylabel('Density')

# Add legend
plt.legend(title='Cluster', labels=[f'Cluster {i}' for i in range(n_clusters)])

plt.show()

# %%
col = 'Holiday'                     


plt.figure(figsize=(10, 6))
sns.kdeplot(data=train_df_with_clusters, x=col, hue='Cluster', fill=True, common_norm=False)
plt.title(f'Density Distribution of {col} Across Clusters')
plt.xlabel(col)
plt.ylabel('Density')

# Add legend
plt.legend(title='Cluster', labels=[f'Cluster {i}' for i in range(n_clusters)])

plt.show()

# %%
col = 'Average_wind'


plt.figure(figsize=(10, 6))
sns.kdeplot(data=train_df_with_clusters, x=col, hue='Cluster', fill=True, common_norm=False)
plt.title(f'Density Distribution of {col} Across Clusters')
plt.xlabel(col)
plt.ylabel('Density')

# Add legend
plt.legend(title='Cluster', labels=[f'Cluster {i}' for i in range(n_clusters)])

plt.show()

# %%
col = 'Max_wind'


plt.figure(figsize=(10, 6))
sns.kdeplot(data=train_df_with_clusters, x=col, hue='Cluster', fill=True, common_norm=False)
plt.title(f'Density Distribution of {col} Across Clusters')
plt.xlabel(col)
plt.ylabel('Density')

# Add legend
plt.legend(title='Cluster', labels=[f'Cluster {i}' for i in range(n_clusters)])

plt.show()

# %%
col = 'Total_precipitation'


plt.figure(figsize=(10, 6))
sns.kdeplot(data=train_df_with_clusters, x=col, hue='Cluster', fill=True, common_norm=False)
plt.title(f'Density Distribution of {col} Across Clusters')
plt.xlabel(col)
plt.ylabel('Density')

# Add legend
plt.legend(title='Cluster', labels=[f'Cluster {i}' for i in range(n_clusters)])

plt.show()

# %%
col = 'Holiday_prev'


plt.figure(figsize=(10, 6))
sns.kdeplot(data=train_df_with_clusters, x=col, hue='Cluster', fill=True, common_norm=False)
plt.title(f'Density Distribution of {col} Across Clusters')
plt.xlabel(col)
plt.ylabel('Density')

# Add legend
plt.legend(title='Cluster', labels=[f'Cluster {i}' for i in range(n_clusters)])

plt.show()

# %%
col = 'ED_1'


plt.figure(figsize=(10, 6))
sns.kdeplot(data=train_df_with_clusters, x=col, hue='Cluster', fill=True, common_norm=False)
plt.title(f'Density Distribution of {col} Across Clusters')
plt.xlabel(col)
plt.ylabel('Density')

# Add legend
plt.legend(title='Cluster', labels=[f'Cluster {i}' for i in range(n_clusters)])

plt.show()
